# %%
import psycopg2
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import sys

# %%
metric = 'cpu.usage.average'
vm = 'DataLake-DBN1'

df = df[df['vm']==vm]
df = df[df['metric']==metric]

df['timestamp'] = pd.to_datetime(df['timestamp'], format="%Y-%m-%d %h:%m:%s")
df.sort_values(by=['timestamp'], inplace=True)
df = df.rename(columns={'timestamp':'ds', 'value': 'y'})
df
# Out:
#                  vm             metric     y                  ds
# 0     DataLake-DBN1  cpu.usage.average  5.11 2025-11-25 17:00:00
# 16    DataLake-DBN1  cpu.usage.average  5.03 2025-11-25 17:30:00
# 32    DataLake-DBN1  cpu.usage.average  4.77 2025-11-25 18:00:00
# 48    DataLake-DBN1  cpu.usage.average  4.68 2025-11-25 18:30:00
# 64    DataLake-DBN1  cpu.usage.average  4.63 2025-11-25 19:00:00
# ...             ...                ...   ...                 ...
# 4752  DataLake-DBN1  cpu.usage.average  5.38 2025-12-01 21:30:00
# 4768  DataLake-DBN1  cpu.usage.average  5.08 2025-12-01 22:00:00
# 4784  DataLake-DBN1  cpu.usage.average  5.13 2025-12-01 22:30:00
# 4800  DataLake-DBN1  cpu.usage.average  5.11 2025-12-01 23:00:00
# 4816  DataLake-DBN1  cpu.usage.average  5.12 2025-12-01 23:30:00
#
# [302 rows x 4 columns]

# %%
# Выгружаем из базы данных
# Конфигурация
DB_CONFIG = {
    'host': 'localhost',
    'port': '5432',
    'database': 'server_metrics',
    'user': 'postgres',
    'password': 'postgres'
}

# %%
def db_export(vm, metric, start_date, end_date):
    """
    Выгрузка данных за период времени

    Args:
        vm: сервер
        metric: метрика
        start_date: выгрузка С
        end_date: выгрузка ПО
    """

    try:
        # Подключение к базе
        conn = psycopg2.connect(**DB_CONFIG)

        # SQL запрос
        query = """
        SELECT
            timestamp,
            value
        FROM server_metrics_fact
        WHERE
            vm = %s
            AND metric = %s
            AND timestamp BETWEEN %s AND %s
        ORDER BY timestamp ASC
        """

        # Выполнение запроса
        df = pd.read_sql_query(query, conn, params=(vm, metric, start_date, end_date))

        # Закрытие соединения
        conn.close()

        if df.empty:
            print(f"Данные не найдены для {vm} - {metric}")
            return None

        # Вывод информации
        print(f"Выгружено {len(df)} записей")
        print(f"Период: {df['timestamp'].min()} - {df['timestamp'].max()}")
        print(f"Значения: {df['value'].min():.2f}% - {df['value'].max():.2f}%")
        print(f"Среднее: {df['value'].mean():.2f}%")

        return df

    except Exception as e:
        print(f"Ошибка: {e}")
        return None

# %%
# Пример использования
data = db_export("DataLake-DBN1", "cpu.usage.average", '2025-11-26 01:00:00', '2025-11-28 01:00:00')
data
# Out:
# Выгружено 97 записей
# Ошибка: No module named 'numpy.rec'
# /var/folders/n6/9hwnx40x1g53w79wdp1sqz5w0000gn/T/ipykernel_64482/3397119797.py:30: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn, params=(vm, metric, start_date, end_date))

# %%
critical_metrics = ['cpu.usage.average', 'cpu.ready.summation', 'mem.usage.average', 'disk.usage.average']

# %%
# Посомтрим как работает модель для пары сервер метрика на данных за 6 дней

# %%
import pandas as pd

# %%
df_train = pd.read_excel('/Users/sweetd0ve/dashboard/data/processed/DataLake-DBN1_cpu.usage.average_2025-11-25 17:00:00_2025-11-30 23:30:00.xlsx')
df_train
# Out:
#                 vm             metric  value           timestamp
# 0    DataLake-DBN1  cpu.usage.average   5.11 2025-11-25 17:00:00
# 1    DataLake-DBN1  cpu.usage.average   5.03 2025-11-25 17:30:00
# 2    DataLake-DBN1  cpu.usage.average   4.77 2025-11-25 18:00:00
# 3    DataLake-DBN1  cpu.usage.average   4.68 2025-11-25 18:30:00
# 4    DataLake-DBN1  cpu.usage.average   4.63 2025-11-25 19:00:00
# ..             ...                ...    ...                 ...
# 249  DataLake-DBN1  cpu.usage.average   5.14 2025-11-30 21:30:00
# 250  DataLake-DBN1  cpu.usage.average   5.18 2025-11-30 22:00:00
# 251  DataLake-DBN1  cpu.usage.average   5.24 2025-11-30 22:30:00
# 252  DataLake-DBN1  cpu.usage.average   5.19 2025-11-30 23:00:00
# 253  DataLake-DBN1  cpu.usage.average   5.11 2025-11-30 23:30:00
#
# [254 rows x 4 columns]

# %%
df_test = pd.read_excel('/Users/sweetd0ve/dashboard/data/processed/DataLake-DBN1_cpu.usage.average_2025-12-01 00:00:00_2025-12-01 23:30:00.xlsx')
df_test
# Out:
#                vm             metric  value           timestamp
# 0   DataLake-DBN1  cpu.usage.average   5.18 2025-12-01 00:00:00
# 1   DataLake-DBN1  cpu.usage.average   5.10 2025-12-01 00:30:00
# 2   DataLake-DBN1  cpu.usage.average   5.23 2025-12-01 01:00:00
# 3   DataLake-DBN1  cpu.usage.average  11.34 2025-12-01 01:30:00
# 4   DataLake-DBN1  cpu.usage.average   5.18 2025-12-01 02:00:00
# 5   DataLake-DBN1  cpu.usage.average   5.12 2025-12-01 02:30:00
# 6   DataLake-DBN1  cpu.usage.average   5.21 2025-12-01 03:00:00
# 7   DataLake-DBN1  cpu.usage.average   5.00 2025-12-01 03:30:00
# 8   DataLake-DBN1  cpu.usage.average   5.03 2025-12-01 04:00:00
# 9   DataLake-DBN1  cpu.usage.average   5.07 2025-12-01 04:30:00
# 10  DataLake-DBN1  cpu.usage.average   5.08 2025-12-01 05:00:00
# 11  DataLake-DBN1  cpu.usage.average   4.94 2025-12-01 05:30:00
# 12  DataLake-DBN1  cpu.usage.average   5.05 2025-12-01 06:00:00
# 13  DataLake-DBN1  cpu.usage.average   4.93 2025-12-01 06:30:00
# 14  DataLake-DBN1  cpu.usage.average   5.05 2025-12-01 07:00:00
# 15  DataLake-DBN1  cpu.usage.average   5.02 2025-12-01 07:30:00
# 16  DataLake-DBN1  cpu.usage.average   5.13 2025-12-01 08:00:00
# 17  DataLake-DBN1  cpu.usage.average   5.18 2025-12-01 08:30:00
# 18  DataLake-DBN1  cpu.usage.average   5.15 2025-12-01 09:00:00
# 19  DataLake-DBN1  cpu.usage.average   5.22 2025-12-01 09:30:00
# 20  DataLake-DBN1  cpu.usage.average   5.22 2025-12-01 10:00:00
# 21  DataLake-DBN1  cpu.usage.average   5.18 2025-12-01 10:30:00
# 22  DataLake-DBN1  cpu.usage.average   5.21 2025-12-01 11:00:00
# 23  DataLake-DBN1  cpu.usage.average   5.27 2025-12-01 11:30:00
# 24  DataLake-DBN1  cpu.usage.average   5.29 2025-12-01 12:00:00
# 25  DataLake-DBN1  cpu.usage.average   5.43 2025-12-01 12:30:00
# 26  DataLake-DBN1  cpu.usage.average   5.34 2025-12-01 13:00:00
# 27  DataLake-DBN1  cpu.usage.average   5.32 2025-12-01 13:30:00
# 28  DataLake-DBN1  cpu.usage.average   5.35 2025-12-01 14:00:00
# 29  DataLake-DBN1  cpu.usage.average   5.34 2025-12-01 14:30:00
# 30  DataLake-DBN1  cpu.usage.average   5.34 2025-12-01 15:00:00
# 31  DataLake-DBN1  cpu.usage.average   5.34 2025-12-01 15:30:00
# 32  DataLake-DBN1  cpu.usage.average   5.29 2025-12-01 16:00:00
# 33  DataLake-DBN1  cpu.usage.average   5.32 2025-12-01 16:30:00
# 34  DataLake-DBN1  cpu.usage.average   5.29 2025-12-01 17:00:00
# 35  DataLake-DBN1  cpu.usage.average   5.31 2025-12-01 17:30:00
# 36  DataLake-DBN1  cpu.usage.average   5.34 2025-12-01 18:00:00
# 37  DataLake-DBN1  cpu.usage.average   5.43 2025-12-01 18:30:00
# 38  DataLake-DBN1  cpu.usage.average   5.52 2025-12-01 19:00:00
# 39  DataLake-DBN1  cpu.usage.average   5.39 2025-12-01 19:30:00
# 40  DataLake-DBN1  cpu.usage.average   5.19 2025-12-01 20:00:00
# 41  DataLake-DBN1  cpu.usage.average   5.02 2025-12-01 20:30:00
# 42  DataLake-DBN1  cpu.usage.average   5.46 2025-12-01 21:00:00
# 43  DataLake-DBN1  cpu.usage.average   5.38 2025-12-01 21:30:00
# 44  DataLake-DBN1  cpu.usage.average   5.08 2025-12-01 22:00:00
# 45  DataLake-DBN1  cpu.usage.average   5.13 2025-12-01 22:30:00
# 46  DataLake-DBN1  cpu.usage.average   5.11 2025-12-01 23:00:00
# 47  DataLake-DBN1  cpu.usage.average   5.12 2025-12-01 23:30:00

# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Using cached prophet-1.2.1-py3-none-macosx_10_11_x86_64.whl (12.7 MB)
# Collecting numpy>=1.15.4
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_x86_64.whl (6.9 MB)
# Collecting matplotlib>=2.0.0
#   Using cached matplotlib-3.9.4-cp39-cp39-macosx_10_12_x86_64.whl (7.9 MB)
# Collecting importlib_resources
#   Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting pandas>=1.0.4
#   Using cached pandas-2.3.3-cp39-cp39-macosx_10_9_x86_64.whl (11.6 MB)
# Collecting cmdstanpy>=1.0.4
#   Using cached cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Collecting tqdm>=4.36.1
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting holidays<1,>=0.25
#   Using cached holidays-0.83-py3-none-any.whl (1.3 MB)
# Collecting stanio<2.0.0,>=0.4.0
#   Using cached stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: python-dateutil in /Users/sweetd0ve/Arina/dashboard/venv/lib/python3.9/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.60.2-cp39-cp39-macosx_10_9_x86_64.whl (2.4 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/sweetd0ve/Arina/dashboard/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.7-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (265 kB)
# Collecting pillow>=8
#   Using cached pillow-11.3.0-cp39-cp39-macosx_10_10_x86_64.whl (5.3 MB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/sweetd0ve/Arina/dashboard/venv/lib/python3.9/site-packages (from importlib_resources->prophet) (3.23.0)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sweetd0ve/Arina/dashboard/venv/lib/python3.9/site-packages (from pandas>=1.0.4->prophet) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/sweetd0ve/Arina/dashboard/venv/lib/python3.9/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Installing collected packages: pytz, numpy, tqdm, stanio, pyparsing, pillow, pandas, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.3.0 contourpy-1.3.0 cycler-0.12.1 fonttools-4.60.2 holidays-0.83 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 numpy-2.0.2 pandas-2.3.3 pillow-11.3.0 prophet-1.2.1 pyparsing-3.3.1 pytz-2025.2 stanio-0.5.1 tqdm-4.67.1
# WARNING: You are using pip version 21.3.1; however, version 25.3 is available.
# You should consider upgrading via the '/Users/sweetd0ve/Arina/dashboard/venv/bin/python -m pip install --upgrade pip' command.

# %%
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# ?Prophet
